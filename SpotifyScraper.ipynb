# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
 def get_spotify_hits(country):
    #gonna have to change the us from a permanent variable to one that shifts
    page = requests.get(f'https://spotifycharts.com/regional/{country}/weekly/latest')
    page
    soup = BeautifulSoup(page.content, 'html.parser')
    #test the soup connection
    table = soup.find('table', attrs={'class': 'chart-table'})

    table_body = table.find('tbody')
    table = []
    #for each entry into the table go get all the information
    for tr in table_body.find_all('tr'):
        #create an empty dictionary to put stuff in
        dict_1 = {}
        #get the name of the artist
        entry_name = tr.find('td', attrs={'class': 'chart-table-track'}).find('span').text
        entry_name = entry_name.replace('by ', '').strip()
        #add it to the dictionary associated with the artist key
        dict_1['artist'] = entry_name
        #get all of the song titles
        title = tr.find('td', attrs={'class': 'chart-table-track'}).find('strong').text
        #add it to the dictionary associated with the song_title key
        dict_1['song_title'] = title
        #get the number of streams
        streaming_number = tr.find('td', attrs={'class': 'chart-table-streams'}).text
        streaming_number = streaming_number.replace(',', '')
        streaming_number = int(streaming_number)
        #add it to the dictionary associated with stream count
        dict_1['stream_count'] = streaming_number
        dict_1[f'{country}'] = country
        table.append(dict_1)
    #drop duplicate entries from list
#     keys = table[0].keys()
#     print(keys)
#     for row in table:
#         with open('spotifyproject_data', 'w') as myfile:
#             wr = csv.DictWriter(myfile, keys)
#             wr.writeheader()
#             wr.writerow(table)
#     #save to csv
    
    f = open("songs.csv", "w")
    writer = csv.DictWriter(
        f, fieldnames=['artist', 'song_title', 'stream_count', country])
    writer.writeheader()
    writer.writerows(
        table)
    f.close()
#     for entry in table:
#         for key, val in entry.items():
#             w.writerow([key, val])
    return table

# %%
get_spotify_hits('us')
# Out:
# dict_keys(['artist', 'song_title', 'stream_count', 'us'])
# [{'artist': 'Arizona Zervas',
#   'song_title': 'ROXANNE',
#   'stream_count': 10919777,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Circles',
#   'stream_count': 8572624,
#   'us': 'us'},
#  {'artist': 'Travis Scott',
#   'song_title': 'HIGHEST IN THE ROOM',
#   'stream_count': 8480933,
#   'us': 'us'},
#  {'artist': 'Juice WRLD',
#   'song_title': 'Bandit (with YoungBoy Never Broke Again)',
#   'stream_count': 7778890,
#   'us': 'us'},
#  {'artist': 'Selena Gomez',
#   'song_title': 'Lose You To Love Me',
#   'stream_count': 7090786,
#   'us': 'us'},
#  {'artist': 'Lewis Capaldi',
#   'song_title': 'Someone You Loved',
#   'stream_count': 6058702,
#   'us': 'us'},
#  {'artist': 'YNW Melly',
#   'song_title': "223's (feat. 9lokknine)",
#   'stream_count': 5924869,
#   'us': 'us'},
#  {'artist': 'blackbear',
#   'song_title': 'hot girl bummer',
#   'stream_count': 5809764,
#   'us': 'us'},
#  {'artist': 'Lil Mosey',
#   'song_title': 'Stuck In A Dream (feat. Gunna)',
#   'stream_count': 5689981,
#   'us': 'us'},
#  {'artist': 'Maroon 5',
#   'song_title': 'Memories',
#   'stream_count': 5660271,
#   'us': 'us'},
#  {'artist': 'Lil Baby',
#   'song_title': 'Woah',
#   'stream_count': 5216559,
#   'us': 'us'},
#  {'artist': 'Young Thug',
#   'song_title': 'Hot (Remix) [feat. Gunna and Travis Scott]',
#   'stream_count': 5214711,
#   'us': 'us'},
#  {'artist': 'Kanye West',
#   'song_title': 'Follow God',
#   'stream_count': 5111357,
#   'us': 'us'},
#  {'artist': 'Tones and I',
#   'song_title': 'Dance Monkey',
#   'stream_count': 4930018,
#   'us': 'us'},
#  {'artist': 'NLE Choppa',
#   'song_title': 'Camelot',
#   'stream_count': 4900212,
#   'us': 'us'},
#  {'artist': 'Dua Lipa',
#   'song_title': "Don't Start Now",
#   'stream_count': 4860747,
#   'us': 'us'},
#  {'artist': 'Dan + Shay',
#   'song_title': '10,000 Hours (with Justin Bieber)',
#   'stream_count': 4746933,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Sunflower - Spider-Man: Into the Spider-Verse',
#   'stream_count': 4630403,
#   'us': 'us'},
#  {'artist': 'Lil Tecca',
#   'song_title': 'Ransom',
#   'stream_count': 4570634,
#   'us': 'us'},
#  {'artist': 'Ant Saunders',
#   'song_title': 'Yellow Hearts',
#   'stream_count': 4207985,
#   'us': 'us'},
#  {'artist': 'Chris Brown',
#   'song_title': 'No Guidance (feat. Drake)',
#   'stream_count': 4166841,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Goodbyes (Feat. Young Thug)',
#   'stream_count': 4096818,
#   'us': 'us'},
#  {'artist': 'DaBaby',
#   'song_title': 'VIBEZ',
#   'stream_count': 4095624,
#   'us': 'us'},
#  {'artist': 'Lizzo',
#   'song_title': 'Truth Hurts',
#   'stream_count': 4045652,
#   'us': 'us'},
#  {'artist': 'Drake',
#   'song_title': 'Money In The Grave (Drake ft. Rick Ross)',
#   'stream_count': 3934547,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Take What You Want (feat. Ozzy Osbourne & Travis Scott)',
#   'stream_count': 3918519,
#   'us': 'us'},
#  {'artist': 'Harry Styles',
#   'song_title': 'Lights Up',
#   'stream_count': 3839540,
#   'us': 'us'},
#  {'artist': 'YoungBoy Never Broke Again',
#   'song_title': 'Make No Sense',
#   'stream_count': 3803206,
#   'us': 'us'},
#  {'artist': 'Mustard',
#   'song_title': "Ballin' (with Roddy Ricch)",
#   'stream_count': 3732536,
#   'us': 'us'},
#  {'artist': 'Quality Control',
#   'song_title': 'Baby (Lil Baby feat. DaBaby)',
#   'stream_count': 3705981,
#   'us': 'us'},
#  {'artist': '21 Savage',
#   'song_title': 'Immortal',
#   'stream_count': 3599336,
#   'us': 'us'},
#  {'artist': 'Billie Eilish',
#   'song_title': 'bad guy',
#   'stream_count': 3548237,
#   'us': 'us'},
#  {'artist': 'SHAED',
#   'song_title': 'Trampoline (with ZAYN)',
#   'stream_count': 3528964,
#   'us': 'us'},
#  {'artist': 'DaBaby',
#   'song_title': 'Suge',
#   'stream_count': 3512359,
#   'us': 'us'},
#  {'artist': 'DaBaby',
#   'song_title': 'BOP',
#   'stream_count': 3450696,
#   'us': 'us'},
#  {'artist': 'Selena Gomez',
#   'song_title': 'Look At Her Now',
#   'stream_count': 3390491,
#   'us': 'us'},
#  {'artist': 'Lil Tjay',
#   'song_title': 'F.N',
#   'stream_count': 3385060,
#   'us': 'us'},
#  {'artist': 'Shawn Mendes',
#   'song_title': 'Señorita',
#   'stream_count': 3296957,
#   'us': 'us'},
#  {'artist': 'Lil Nas X',
#   'song_title': 'Panini',
#   'stream_count': 3290350,
#   'us': 'us'},
#  {'artist': 'Chance the Rapper',
#   'song_title': 'Hot Shower',
#   'stream_count': 3206821,
#   'us': 'us'},
#  {'artist': '24kGoldn',
#   'song_title': 'VALENTINO',
#   'stream_count': 3201117,
#   'us': 'us'},
#  {'artist': 'Ed Sheeran',
#   'song_title': 'Beautiful People (feat. Khalid)',
#   'stream_count': 3185223,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Enemies (feat. DaBaby)',
#   'stream_count': 3167438,
#   'us': 'us'},
#  {'artist': 'Sam Smith',
#   'song_title': 'How Do You Sleep?',
#   'stream_count': 3162439,
#   'us': 'us'},
#  {'artist': 'Lizzo',
#   'song_title': 'Good as Hell (feat. Ariana Grande) - Remix',
#   'stream_count': 3022917,
#   'us': 'us'},
#  {'artist': 'Young Thug',
#   'song_title': 'Hot (feat. Gunna)',
#   'stream_count': 3006887,
#   'us': 'us'},
#  {'artist': 'Young Thug',
#   'song_title': 'The London (feat. J. Cole & Travis Scott)',
#   'stream_count': 3002140,
#   'us': 'us'},
#  {'artist': 'Lil Tecca',
#   'song_title': 'Did It Again',
#   'stream_count': 2974142,
#   'us': 'us'},
#  {'artist': 'Halsey',
#   'song_title': 'Graveyard',
#   'stream_count': 2850293,
#   'us': 'us'},
#  {'artist': 'Internet Money',
#   'song_title': 'Somebody',
#   'stream_count': 2839629,
#   'us': 'us'},
#  {'artist': 'J. Cole',
#   'song_title': 'MIDDLE CHILD',
#   'stream_count': 2810162,
#   'us': 'us'},
#  {'artist': 'Young Thug',
#   'song_title': 'Bad Bad Bad (feat. Lil Baby)',
#   'stream_count': 2758310,
#   'us': 'us'},
#  {'artist': 'Polo G',
#   'song_title': 'Pop Out (feat. Lil Tjay)',
#   'stream_count': 2721960,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Better Together',
#   'stream_count': 2717669,
#   'us': 'us'},
#  {'artist': 'Roddy Ricch',
#   'song_title': 'Start Wit Me (feat. Gunna)',
#   'stream_count': 2694977,
#   'us': 'us'},
#  {'artist': 'Frank Ocean',
#   'song_title': 'In My Room',
#   'stream_count': 2692832,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Saint-Tropez',
#   'stream_count': 2659824,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Wow.',
#   'stream_count': 2633172,
#   'us': 'us'},
#  {'artist': 'Ellie Goulding',
#   'song_title': 'Hate Me (with Juice WRLD)',
#   'stream_count': 2630682,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': "Even Though I'm Leaving",
#   'stream_count': 2586525,
#   'us': 'us'},
#  {'artist': 'YNW Melly',
#   'song_title': 'Murder On My Mind',
#   'stream_count': 2516505,
#   'us': 'us'},
#  {'artist': 'Juice WRLD',
#   'song_title': 'Lucid Dreams',
#   'stream_count': 2508872,
#   'us': 'us'},
#  {'artist': 'Camila Cabello',
#   'song_title': 'Liar',
#   'stream_count': 2504661,
#   'us': 'us'},
#  {'artist': 'Ali Gatie',
#   'song_title': "It's You",
#   'stream_count': 2500978,
#   'us': 'us'},
#  {'artist': 'Y2K',
#   'song_title': 'Lalala',
#   'stream_count': 2492922,
#   'us': 'us'},
#  {'artist': 'Doja Cat',
#   'song_title': 'Juicy',
#   'stream_count': 2492472,
#   'us': 'us'},
#  {'artist': 'Zedd',
#   'song_title': 'Good Thing (with Kehlani)',
#   'stream_count': 2442241,
#   'us': 'us'},
#  {'artist': 'Mariah Carey',
#   'song_title': 'All I Want for Christmas Is You',
#   'stream_count': 2428042,
#   'us': 'us'},
#  {'artist': 'Lil Baby',
#   'song_title': 'Drip Too Hard (Lil Baby & Gunna)',
#   'stream_count': 2426491,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Beer Never Broke My Heart',
#   'stream_count': 2421600,
#   'us': 'us'},
#  {'artist': 'Doja Cat',
#   'song_title': 'Candy',
#   'stream_count': 2404002,
#   'us': 'us'},
#  {'artist': 'Travis Scott',
#   'song_title': 'SICKO MODE',
#   'stream_count': 2380175,
#   'us': 'us'},
#  {'artist': 'Joji',
#   'song_title': 'SLOW DANCING IN THE DARK',
#   'stream_count': 2378839,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'What You See Is What You Get',
#   'stream_count': 2377666,
#   'us': 'us'},
#  {'artist': 'Meek Mill',
#   'song_title': 'Going Bad (feat. Drake)',
#   'stream_count': 2363505,
#   'us': 'us'},
#  {'artist': 'Billie Eilish',
#   'song_title': "when the party's over",
#   'stream_count': 2327159,
#   'us': 'us'},
#  {'artist': 'Khalid',
#   'song_title': 'Talk (feat. Disclosure)',
#   'stream_count': 2309696,
#   'us': 'us'},
#  {'artist': 'A Boogie Wit da Hoodie',
#   'song_title': 'Swervin (feat. 6ix9ine)',
#   'stream_count': 2309437,
#   'us': 'us'},
#  {'artist': 'Ed Sheeran',
#   'song_title': 'South of the Border (feat. Camila Cabello & Cardi B)',
#   'stream_count': 2281375,
#   'us': 'us'},
#  {'artist': 'Old Dominion',
#   'song_title': 'One Man Band',
#   'stream_count': 2259856,
#   'us': 'us'},
#  {'artist': 'Billie Eilish',
#   'song_title': 'everything i wanted',
#   'stream_count': 2254628,
#   'us': 'us'},
#  {'artist': 'YoungBoy Never Broke Again',
#   'song_title': 'Self Control',
#   'stream_count': 2248337,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': "Hollywood's Bleeding",
#   'stream_count': 2229754,
#   'us': 'us'},
#  {'artist': 'Taylor Swift',
#   'song_title': 'Lover',
#   'stream_count': 2215321,
#   'us': 'us'},
#  {'artist': 'Billie Eilish',
#   'song_title': 'lovely (with Khalid)',
#   'stream_count': 2209278,
#   'us': 'us'},
#  {'artist': 'Juice WRLD',
#   'song_title': 'Robbery',
#   'stream_count': 2205656,
#   'us': 'us'},
#  {'artist': 'Bazzi',
#   'song_title': 'I.F.L.Y.',
#   'stream_count': 2200879,
#   'us': 'us'},
#  {'artist': 'Lil Tecca',
#   'song_title': 'Ransom (with Juice WRLD) - Remix',
#   'stream_count': 2193541,
#   'us': 'us'},
#  {'artist': 'Frank Ocean',
#   'song_title': 'Chanel',
#   'stream_count': 2180532,
#   'us': 'us'},
#  {'artist': 'Tyler, The Creator',
#   'song_title': 'EARFQUAKE',
#   'stream_count': 2169524,
#   'us': 'us'},
#  {'artist': 'Major Lazer',
#   'song_title': 'Trigger',
#   'stream_count': 2163985,
#   'us': 'us'},
#  {'artist': 'Marshmello',
#   'song_title': 'One Thing Right',
#   'stream_count': 2156075,
#   'us': 'us'},
#  {'artist': 'Lil Nas X',
#   'song_title': 'Panini - DaBaby Remix',
#   'stream_count': 2154485,
#   'us': 'us'},
#  {'artist': 'Ed Sheeran',
#   'song_title': "I Don't Care (with Justin Bieber)",
#   'stream_count': 2144618,
#   'us': 'us'},
#  {'artist': 'Dan + Shay',
#   'song_title': 'Speechless',
#   'stream_count': 2109710,
#   'us': 'us'},
#  {'artist': 'Ariana Grande',
#   'song_title': 'Bad To You (with Normani & Nicki Minaj)',
#   'stream_count': 2095815,
#   'us': 'us'},
#  {'artist': 'Niall Horan',
#   'song_title': 'Nice To Meet Ya',
#   'stream_count': 2088268,
#   'us': 'us'},
#  {'artist': 'Lil Uzi Vert',
#   'song_title': 'Sanguine Paradise',
#   'stream_count': 2086901,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Does To Me (feat. Eric Church)',
#   'stream_count': 2082848,
#   'us': 'us'},
#  {'artist': 'Normani',
#   'song_title': 'Motivation',
#   'stream_count': 2060051,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'On The Road (feat. Meek Mill & Lil Baby)',
#   'stream_count': 2053033,
#   'us': 'us'},
#  {'artist': 'Lil Tecca',
#   'song_title': 'Love Me',
#   'stream_count': 2052495,
#   'us': 'us'},
#  {'artist': 'Tory Lanez',
#   'song_title': 'Jerry Sprunger (with T-Pain)',
#   'stream_count': 2048798,
#   'us': 'us'},
#  {'artist': 'Drake',
#   'song_title': 'Behind Barz - Bonus',
#   'stream_count': 2038287,
#   'us': 'us'},
#  {'artist': 'The Black Eyed Peas',
#   'song_title': 'RITMO (Bad Boys For Life)',
#   'stream_count': 2017351,
#   'us': 'us'},
#  {'artist': 'The Chainsmokers',
#   'song_title': 'Takeaway',
#   'stream_count': 2013244,
#   'us': 'us'},
#  {'artist': 'YoungBoy Never Broke Again',
#   'song_title': 'Hot Now',
#   'stream_count': 2009425,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'I Fall Apart',
#   'stream_count': 1988843,
#   'us': 'us'},
#  {'artist': 'Khalid',
#   'song_title': 'Better',
#   'stream_count': 1985751,
#   'us': 'us'},
#  {'artist': 'Regard',
#   'song_title': 'Ride It',
#   'stream_count': 1959265,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'rockstar (feat. 21 Savage)',
#   'stream_count': 1950569,
#   'us': 'us'},
#  {'artist': 'Ariana Grande',
#   'song_title': '7 rings',
#   'stream_count': 1949719,
#   'us': 'us'},
#  {'artist': 'J Balvin',
#   'song_title': 'LA CANCIÓN',
#   'stream_count': 1949184,
#   'us': 'us'},
#  {'artist': 'Travis Scott',
#   'song_title': 'goosebumps',
#   'stream_count': 1948990,
#   'us': 'us'},
#  {'artist': 'Lizzo',
#   'song_title': 'Good As Hell',
#   'stream_count': 1948501,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Beautiful Crazy',
#   'stream_count': 1945677,
#   'us': 'us'},
#  {'artist': 'Bad Bunny',
#   'song_title': 'Callaita',
#   'stream_count': 1944871,
#   'us': 'us'},
#  {'artist': 'Calboy',
#   'song_title': 'Envy Me',
#   'stream_count': 1932010,
#   'us': 'us'},
#  {'artist': 'NLE Choppa',
#   'song_title': 'Shotta Flow (Feat. Blueface) [Remix]',
#   'stream_count': 1929431,
#   'us': 'us'},
#  {'artist': 'JP Saxe',
#   'song_title': 'If The World Was Ending (feat. Julia Michaels)',
#   'stream_count': 1926030,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Reasons',
#   'stream_count': 1923450,
#   'us': 'us'},
#  {'artist': 'XXXTENTACION',
#   'song_title': 'SAD!',
#   'stream_count': 1919089,
#   'us': 'us'},
#  {'artist': 'Trippie Redd',
#   'song_title': 'Love Me More',
#   'stream_count': 1915161,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Better Now',
#   'stream_count': 1893320,
#   'us': 'us'},
#  {'artist': 'Taylor Swift',
#   'song_title': 'You Need To Calm Down',
#   'stream_count': 1888373,
#   'us': 'us'},
#  {'artist': 'benny blanco',
#   'song_title': 'Eastside (with Halsey & Khalid)',
#   'stream_count': 1883955,
#   'us': 'us'},
#  {'artist': 'The Chainsmokers',
#   'song_title': 'Push My Luck',
#   'stream_count': 1881234,
#   'us': 'us'},
#  {'artist': 'XXXTENTACION',
#   'song_title': 'Jocelyn Flores',
#   'stream_count': 1880482,
#   'us': 'us'},
#  {'artist': 'Diplo',
#   'song_title': 'Heartless (feat. Morgan Wallen)',
#   'stream_count': 1880334,
#   'us': 'us'},
#  {'artist': 'Post Malone',
#   'song_title': 'Die For Me (feat. Future & Halsey)',
#   'stream_count': 1859349,
#   'us': 'us'},
#  {'artist': 'Megan Thee Stallion',
#   'song_title': 'Cash Shit (feat. DaBaby)',
#   'stream_count': 1858536,
#   'us': 'us'},
#  {'artist': 'Mustard',
#   'song_title': 'Pure Water (with Migos)',
#   'stream_count': 1848939,
#   'us': 'us'},
#  {'artist': 'Mustard',
#   'song_title': 'Baguettes in the Face (feat. NAV, Playboi Carti & A Boogie Wit da Hoodie)',
#   'stream_count': 1846172,
#   'us': 'us'},
#  {'artist': 'Kanye West',
#   'song_title': 'Closed On Sunday',
#   'stream_count': 1841050,
#   'us': 'us'},
#  {'artist': 'Jonas Brothers',
#   'song_title': 'Sucker',
#   'stream_count': 1838729,
#   'us': 'us'},
#  {'artist': 'Lil Nas X',
#   'song_title': 'Old Town Road - Remix',
#   'stream_count': 1838169,
#   'us': 'us'},
#  {'artist': 'Lauv',
#   'song_title': 'Feelings',
#   'stream_count': 1835888,
#   'us': 'us'},
#  {'artist': 'Marshmello',
#   'song_title': 'Happier',
#   'stream_count': 1834371,
#   'us': 'us'},
#  {'artist': 'Camila Cabello',
#   'song_title': 'Easy',
#   'stream_count': 1830667,
#   'us': 'us'},
#  {'artist': 'Lewis Capaldi',
#   'song_title': 'Bruises',
#   'stream_count': 1825515,
#   'us': 'us'},
#  {'artist': 'Saweetie',
#   'song_title': 'My Type',
#   'stream_count': 1808349,
#   'us': 'us'},
#  {'artist': 'Lil Mosey',
#   'song_title': 'G Walk (with Chris Brown)',
#   'stream_count': 1807392,
#   'us': 'us'},
#  {'artist': 'Halsey',
#   'song_title': 'Without Me',
#   'stream_count': 1799053,
#   'us': 'us'},
#  {'artist': 'Russ',
#   'song_title': 'BEST ON EARTH (feat. BIA)',
#   'stream_count': 1792247,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': '1, 2 Many',
#   'stream_count': 1790754,
#   'us': 'us'},
#  {'artist': 'Tame Impala',
#   'song_title': 'The Less I Know The Better',
#   'stream_count': 1786681,
#   'us': 'us'},
#  {'artist': 'Ariana Grande',
#   'song_title': 'boyfriend (with Social House)',
#   'stream_count': 1781106,
#   'us': 'us'},
#  {'artist': 'Lil Mosey',
#   'song_title': 'Noticed',
#   'stream_count': 1775057,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'All Over Again',
#   'stream_count': 1771197,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Blue Collar Boys',
#   'stream_count': 1766086,
#   'us': 'us'},
#  {'artist': 'Summer Walker',
#   'song_title': 'Playing Games (with Bryson Tiller) - Extended Version',
#   'stream_count': 1761902,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Nothing Like You',
#   'stream_count': 1754191,
#   'us': 'us'},
#  {'artist': 'Ariana Grande',
#   'song_title': 'thank u, next',
#   'stream_count': 1749225,
#   'us': 'us'},
#  {'artist': 'Kanye West',
#   'song_title': 'On God',
#   'stream_count': 1747506,
#   'us': 'us'},
#  {'artist': 'iann dior',
#   'song_title': 'gone girl',
#   'stream_count': 1742350,
#   'us': 'us'},
#  {'artist': 'Noah Cyrus',
#   'song_title': 'July',
#   'stream_count': 1738149,
#   'us': 'us'},
#  {'artist': 'Megan Thee Stallion',
#   'song_title': 'Hot Girl Summer (feat. Nicki Minaj & Ty Dolla $ign)',
#   'stream_count': 1721597,
#   'us': 'us'},
#  {'artist': 'Lil Mosey',
#   'song_title': 'Live This Wild',
#   'stream_count': 1710526,
#   'us': 'us'},
#  {'artist': 'Juice WRLD',
#   'song_title': 'All Girls Are The Same',
#   'stream_count': 1694464,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Refrigerator Door',
#   'stream_count': 1692671,
#   'us': 'us'},
#  {'artist': 'Shawn Mendes',
#   'song_title': "If I Can't Have You",
#   'stream_count': 1682897,
#   'us': 'us'},
#  {'artist': 'BTS',
#   'song_title': 'Make It Right (feat. Lauv)',
#   'stream_count': 1667220,
#   'us': 'us'},
#  {'artist': 'Gunna',
#   'song_title': 'Baby Birkin',
#   'stream_count': 1661279,
#   'us': 'us'},
#  {'artist': 'Summer Walker',
#   'song_title': 'Come Thru (with Usher)',
#   'stream_count': 1656953,
#   'us': 'us'},
#  {'artist': 'XXXTENTACION',
#   'song_title': 'Moonlight',
#   'stream_count': 1653428,
#   'us': 'us'},
#  {'artist': 'DaBaby',
#   'song_title': 'INTRO',
#   'stream_count': 1652819,
#   'us': 'us'},
#  {'artist': 'Brenda Lee',
#   'song_title': "Rockin' Around The Christmas Tree",
#   'stream_count': 1650329,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Dear Today',
#   'stream_count': 1648081,
#   'us': 'us'},
#  {'artist': 'Ariana Grande',
#   'song_title': 'Santa Tell Me',
#   'stream_count': 1645173,
#   'us': 'us'},
#  {'artist': 'XXXTENTACION',
#   'song_title': 'Fuck Love (feat. Trippie Redd)',
#   'stream_count': 1638718,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'New Every Day',
#   'stream_count': 1637787,
#   'us': 'us'},
#  {'artist': 'Ski Mask The Slump God',
#   'song_title': 'Faucet Failure',
#   'stream_count': 1633075,
#   'us': 'us'},
#  {'artist': 'Kanye West',
#   'song_title': 'Selah',
#   'stream_count': 1629990,
#   'us': 'us'},
#  {'artist': 'Lil Baby',
#   'song_title': 'Yes Indeed',
#   'stream_count': 1624756,
#   'us': 'us'},
#  {'artist': 'Morgan Wallen',
#   'song_title': 'Whiskey Glasses',
#   'stream_count': 1624454,
#   'us': 'us'},
#  {'artist': 'Lil Uzi Vert',
#   'song_title': 'XO Tour Llif3',
#   'stream_count': 1622446,
#   'us': 'us'},
#  {'artist': 'A Boogie Wit da Hoodie',
#   'song_title': 'Look Back at It',
#   'stream_count': 1610669,
#   'us': 'us'},
#  {'artist': 'Anuel AA',
#   'song_title': 'China',
#   'stream_count': 1608692,
#   'us': 'us'},
#  {'artist': 'H.E.R.',
#   'song_title': 'Best Part (feat. Daniel Caesar)',
#   'stream_count': 1608146,
#   'us': 'us'},
#  {'artist': 'Wham!',
#   'song_title': 'Last Christmas',
#   'stream_count': 1604050,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Every Little Bit Helps',
#   'stream_count': 1602246,
#   'us': 'us'},
#  {'artist': 'Bazzi',
#   'song_title': 'Paradise',
#   'stream_count': 1599130,
#   'us': 'us'},
#  {'artist': 'DaBaby',
#   'song_title': 'TOES (feat. Lil Baby & Moneybagg Yo)',
#   'stream_count': 1593083,
#   'us': 'us'},
#  {'artist': '21 Savage',
#   'song_title': 'a lot',
#   'stream_count': 1588341,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': "Lovin' On You",
#   'stream_count': 1584882,
#   'us': 'us'},
#  {'artist': 'Kanye West',
#   'song_title': 'Use This Gospel',
#   'stream_count': 1576209,
#   'us': 'us'},
#  {'artist': 'Kanye West',
#   'song_title': 'Everything We Need',
#   'stream_count': 1569236,
#   'us': 'us'},
#  {'artist': 'Khalid',
#   'song_title': 'Saturday Nights',
#   'stream_count': 1567768,
#   'us': 'us'},
#  {'artist': 'Jhay Cortez',
#   'song_title': 'No Me Conoce - Remix',
#   'stream_count': 1560557,
#   'us': 'us'},
#  {'artist': 'Diplo',
#   'song_title': 'Lonely (with Jonas Brothers)',
#   'stream_count': 1559175,
#   'us': 'us'},
#  {'artist': 'Lil Uzi Vert',
#   'song_title': '20 Min',
#   'stream_count': 1558975,
#   'us': 'us'},
#  {'artist': 'Dean Lewis',
#   'song_title': 'Be Alright',
#   'stream_count': 1548752,
#   'us': 'us'},
#  {'artist': '5 Seconds of Summer',
#   'song_title': 'Teeth',
#   'stream_count': 1539494,
#   'us': 'us'},
#  {'artist': 'Lil Skies',
#   'song_title': 'I',
#   'stream_count': 1538182,
#   'us': 'us'},
#  {'artist': 'Billie Eilish',
#   'song_title': 'i love you',
#   'stream_count': 1534984,
#   'us': 'us'},
#  {'artist': 'Luke Combs',
#   'song_title': 'Moon Over Mexico',
#   'stream_count': 1525129,
#   'us': 'us'},
#  {'artist': 'Kodak Black',
#   'song_title': 'ZEZE',
#   'stream_count': 1519761,
#   'us': 'us'},
#  {'artist': 'BobHelms',
#   'song_title': 'Jingle Bell Rock',
#   'stream_count': 1519537,
#   'us': 'us'},
#  {'artist': "Why Don't We",
#   'song_title': 'What Am I',
#   'stream_count': 1511298,
#   'us': 'us'},
#  {'artist': 'James Arthur',
#   'song_title': "Say You Won't Let Go",
#   'stream_count': 1510016,
#   'us': 'us'}]

# %%
countries = ['us', 'gb', 'ad', 'ar', 'at', 'au', 'be', 'bg', 'bo', 'br',
'ca', 'ch', 'cl', 'co', 'cr', 'cy', 'cz', 'de', 'dk', 'do', 'ec', 'ee',
'es', 'fi', 'fr', 'gr', 'gt', 'hk', 'hn', 'hu', 'id', 'ie', 'il', 'in',
'is', 'it', 'jp', 'lt', 'lu', 'lv', 'mt', 'mx', 'my', 'ni', 'nl', 'no',
'nz', 'pa', 'pe', 'ph', 'pl', 'pt', 'py', 'ro', 'se', 'sg', 'sk', 'sv',
'th', 'tr', 'tw', 'uy', 'vn', 'za']

# %%
def all_country_grabber(countries_list):
    for country in countries:
        get_spotify_hits(country)
    return

# %%
all_country_grabber(countries)
